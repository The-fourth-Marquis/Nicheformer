# %%
import scanpy as sc
import sys

import os 
import sys
import pandas as pd
import scanpy as sc
from scipy.sparse import csr_matrix

from nicheformer.data.constants import DefaultPaths, ObsConstants, UnsConstants, VarConstants, AssayOntologyTermId, SexOntologyTermId, OrganismOntologyTermId, TissueOntologyTermId, SuspensionTypeId
from nicheformer.data.validate import validate

# %%
cosmx_NormalLiver_fullvis = sc.read_h5ad("/mnt/172/wh/25-12/spatial/raw/cosmx_liver_full_h5ad_export/cosmx_NormalLiver_fullvis.h5ad")
print(cosmx_NormalLiver_fullvis)
print(cosmx_NormalLiver_fullvis.obsm.keys())
# Out:
# AnnData object with n_obs × n_vars = 332877 × 1000
#     obs: 'RNA_pca_cluster_default', 'RNA_pca_cluster_default.1', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_negprobes', 'nFeature_negprobes', 'nCount_falsecode', 'nFeature_falsecode', 'fov', 'Area', 'AspectRatio', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CK8.18', 'Max.CK8.18', 'Mean.Membrane', 'Max.Membrane', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'assay_type', 'Run_name', 'slide_ID_numeric', 'Run_Tissue_name', 'Panel', 'Mean.Yellow', 'Max.Yellow', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'cell_ID', 'x_FOV_px', 'y_FOV_px', 'x_slide_mm', 'y_slide_mm', 'propNegative', 'complexity', 'errorCtEstimate', 'percOfDataFromError', 'qcFlagsRNACounts', 'qcFlagsCellCounts', 'qcFlagsCellPropNeg', 'qcFlagsCellComplex', 'qcFlagsCellArea', 'median_negprobes', 'negprobes_quantile_0.9', 'median_RNA', 'RNA_quantile_0.9', 'nCell', 'nCount', 'nCountPerCell', 'nFeaturePerCell', 'propNegativeCellAvg', 'complexityCellAvg', 'errorCtPerCellEstimate', 'percOfDataFromErrorPerCell', 'qcFlagsFOV', 'cellType', 'niche'
#     uns: 'falsecode_features', 'negprobes_features'
#     obsm: 'X_pca', 'X_umap', 'X_umap_bySlide', 'falsecode_counts', 'negprobes_counts', 'spatial', 'spatial_fov_px'
#     layers: 'counts', 'data'
# KeysView(AxisArrays with keys: X_pca, X_umap, X_umap_bySlide, falsecode_counts, negprobes_counts, spatial, spatial_fov_px)

# %%
cosmx_NormalLiver_fullvis.obs['niche']
# Out:
# c_1_100_10      Zone_3a
# c_1_100_1078    Zone_2a
# c_1_100_1135    Zone_2a
# c_1_100_267     Zone_2a
# c_1_100_732     Zone_2a
#                  ...
# c_1_9_981       Zone_2b
# c_1_9_982       Zone_2b
# c_1_9_985       Zone_2b
# c_1_9_987       Zone_2b
# c_1_9_995       Zone_2b
# Name: niche, Length: 332877, dtype: category
# Categories (6, object): ['Zone_1a/PV', 'Zone_1b', 'Zone_2a', 'Zone_2b', 'Zone_3a', 'Zone_3b/CV']

# %%
path = "mnt/172/wh/25-12/spatial"
raw_path = f"{path}/raw"
preprocessed_path = f"{path}/preprocessed"

# %%
cosmx_human_liver_cancer = sc.read_h5ad("/mnt/172/wh/25-12/spatial/preprocessed/nanostring_cosmx_human_liver_cancer.h5ad")
print(cosmx_human_liver_cancer)
print(cosmx_human_liver_cancer.obsm.keys())
# Out:
# AnnData object with n_obs × n_vars = 460441 × 952
#     obs: 'RNA_pca_cluster_default', 'RNA_pca_cluster_default.1', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_negprobes', 'nFeature_negprobes', 'nCount_falsecode', 'nFeature_falsecode', 'fov', 'Area', 'AspectRatio', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CK8.18', 'Max.CK8.18', 'Mean.Membrane', 'Max.Membrane', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'assay_type', 'Run_name', 'slide_ID_numeric', 'Run_Tissue_name', 'Panel', 'Mean.Yellow', 'Max.Yellow', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'cell_ID', 'x_FOV_px', 'y_FOV_px', 'x_slide_mm', 'y_slide_mm', 'propNegative', 'complexity', 'errorCtEstimate', 'percOfDataFromError', 'qcFlagsRNACounts', 'qcFlagsCellCounts', 'qcFlagsCellPropNeg', 'qcFlagsCellComplex', 'qcFlagsCellArea', 'median_negprobes', 'negprobes_quantile_0.9', 'median_RNA', 'RNA_quantile_0.9', 'nCell', 'nCount', 'nCountPerCell', 'nFeaturePerCell', 'propNegativeCellAvg', 'complexityCellAvg', 'errorCtPerCellEstimate', 'percOfDataFromErrorPerCell', 'qcFlagsFOV', 'cellType', 'niche', 'x', 'y', 'assay_ontology_term_id', 'sex_ontology_term_id', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'donor_id', 'condition_id', 'tissue_type', 'library_key', 'n_genes', 'assay', 'organism', 'sex', 'tissue', 'dataset', 'nicheformer_split', 'author_cell_type', 'region', 'batch'
#     var: 'gene_name', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'falsecode_features', 'negprobes_features', 'nicheformer_version', 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap', 'X_umap_bySlide', 'falsecode_counts', 'negprobes_counts', 'spatial', 'spatial_fov_px'
#     layers: 'counts', 'data'
# KeysView(AxisArrays with keys: X_pca, X_umap, X_umap_bySlide, falsecode_counts, negprobes_counts, spatial, spatial_fov_px)

# %%
cosmx_human_liver_cancer.obs
# Out:
#              RNA_pca_cluster_default  RNA_pca_cluster_default.1 orig.ident  \
# c_2_100_733                        5                          8          c
# c_2_101_240                        2                          6          c
# c_2_101_339                        2                          6          c
# c_2_101_452                        5                          8          c
# c_2_102_179                        2                          6          c
# ...                              ...                        ...        ...
# c_2_9_945                          8                          3          c
# c_2_9_947                          8                          3          c
# c_2_9_948                          4                         12          c
# c_2_9_949                          1                          1          c
# c_2_9_95                           1                          9          c
#
#              nCount_RNA  nFeature_RNA  nCount_negprobes  nFeature_negprobes  \
# c_2_100_733         335           139                 1                   1
# c_2_101_240        2865           406                 0                   0
# c_2_101_339        3277           394                 2                   2
# c_2_101_452        1300           303                 0                   0
# c_2_102_179        7070           534                 1                   1
# ...                 ...           ...               ...                 ...
# c_2_9_945            54            37                 0                   0
# c_2_9_947            48            36                 1                   1
# c_2_9_948           176            74                 1                   1
# c_2_9_949            51            32                 0                   0
# c_2_9_95            593           188                 0                   0
#
#              nCount_falsecode  nFeature_falsecode  fov  ...  n_genes  assay  \
# c_2_100_733                 1                   1  100  ...      139  CosMx
# c_2_101_240                 5                   5  101  ...      406  CosMx
# c_2_101_339                 7                   6  101  ...      394  CosMx
# c_2_101_452                 4                   4  101  ...      303  CosMx
# c_2_102_179                15                  14  102  ...      534  CosMx
# ...                       ...                 ...  ...  ...      ...    ...
# c_2_9_945                   0                   0    9  ...       37  CosMx
# c_2_9_947                   0                   0    9  ...       36  CosMx
# c_2_9_948                   0                   0    9  ...       74  CosMx
# c_2_9_949                   0                   0    9  ...       32  CosMx
# c_2_9_95                    0                   0    9  ...      188  CosMx
#
#                  organism      sex  tissue  \
# c_2_100_733  Homo sapiens  unknown   liver
# c_2_101_240  Homo sapiens  unknown   liver
# c_2_101_339  Homo sapiens  unknown   liver
# c_2_101_452  Homo sapiens  unknown   liver
# c_2_102_179  Homo sapiens  unknown   liver
# ...                   ...      ...     ...
# c_2_9_945    Homo sapiens  unknown   liver
# c_2_9_947    Homo sapiens  unknown   liver
# c_2_9_948    Homo sapiens  unknown   liver
# c_2_9_949    Homo sapiens  unknown   liver
# c_2_9_95     Homo sapiens  unknown   liver
#
#                                          dataset  nicheformer_split  \
# c_2_100_733  nanostring_cosmx_human_liver_cancer              train
# c_2_101_240  nanostring_cosmx_human_liver_cancer              train
# c_2_101_339  nanostring_cosmx_human_liver_cancer              train
# c_2_101_452  nanostring_cosmx_human_liver_cancer              train
# c_2_102_179  nanostring_cosmx_human_liver_cancer              train
# ...                                          ...                ...
# c_2_9_945    nanostring_cosmx_human_liver_cancer              train
# c_2_9_947    nanostring_cosmx_human_liver_cancer              train
# c_2_9_948    nanostring_cosmx_human_liver_cancer              train
# c_2_9_949    nanostring_cosmx_human_liver_cancer              train
# c_2_9_95     nanostring_cosmx_human_liver_cancer              train
#
#                          author_cell_type  region  batch
# c_2_100_733                       tumor_2     nan      2
# c_2_101_240                       tumor_1     nan      2
# c_2_101_339                       tumor_1     nan      2
# c_2_101_452                       tumor_1     nan      2
# c_2_102_179                       tumor_1     nan      2
# ...                                   ...     ...    ...
# c_2_9_945        Inflammatory.macrophages     nan      2
# c_2_9_947    Non.inflammatory.macrophages     nan      2
# c_2_9_948                         tumor_1     nan      2
# c_2_9_949                         tumor_1     nan      2
# c_2_9_95                          tumor_1     nan      2
#
# [460441 rows x 84 columns]

# %%
cosmx_NormalLiver_fullvis.var = cosmx_NormalLiver_fullvis.var.reset_index().rename(columns={'index': 'gene_name'}).set_index('gene_ids')
cosmx_NormalLiver_fullvis.var.index.name = None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_400857/1116920486.py in ?()
# ----> 1 cosmx_NormalLiver_fullvis.var = cosmx_NormalLiver_fullvis.var.reset_index().rename(columns={'index': 'gene_name'}).set_index('gene_ids')
#       2 cosmx_NormalLiver_fullvis.var.index.name = None
#
# ~/code/25-12/nicheformer/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     307                     msg.format(arguments=arguments),
#     308                     FutureWarning,
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#
# ~/code/25-12/nicheformer/.venv/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5499                     if not found:
#    5500                         missing.append(col)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#    5506             frame = self
#
# KeyError: "None of ['gene_ids'] are in the columns"

# %%
cosmx_NormalLiver_fullvis.var.keys()
# Out:
# Index([], dtype='object')

# %%
adata.var = adata.var.reset_index().rename(columns={'index': 'gene_name'}).set_index('gene_ids')
adata.var.index.name = None

# setting MERFISH for now until an official ontology term is released
assay = str(AssayOntologyTermId.MERFISH_SPATIAL.value)
sex = str(SexOntologyTermId.UNKNOWN.value)
organism = str(OrganismOntologyTermId.HUMAN.value)
organism_validator = "human"
tissue = str(TissueOntologyTermId.LUNG.value)
suspension_type = str(SuspensionTypeId.SPATIAL.value)
tissue_type = "tissue"

adata.X = csr_matrix(adata.X)
adata.obs[ObsConstants.SPATIAL_X] = adata.obs['x_centroid']
adata.obs[ObsConstants.SPATIAL_Y] = adata.obs['y_centroid']
adata.obs[ObsConstants.ASSAY_ONTOLOGY_TERM_ID] = pd.Categorical([assay for i in range(len(adata))])
adata.obs[ObsConstants.SEX_ONTOLOGY_TERM_ID] = pd.Categorical([sex for i in range(len(adata))])
adata.obs[ObsConstants.ORGANISM_ONTOLOGY_TERM_ID] = pd.Categorical([organism for i in range(len(adata))])
adata.obs[ObsConstants.TISSUE_ONTOLOGY_TERM_ID] = pd.Categorical([tissue for i in range(len(adata))])
adata.obs[ObsConstants.SUSPENSION_TYPE] = pd.Categorical([suspension_type for i in range(len(adata))])

adata.obs[ObsConstants.DONOR_ID] = pd.Categorical(['Xenium_Preview_Human_Non_diseased_Lung_With_Add_on_FFPE_outs' for i in range(len(adata))])
adata.obs[ObsConstants.CONDITION_ID] = pd.Categorical(['non diseased' for i in range(len(adata))])
adata.obs[ObsConstants.TISSUE_TYPE] = pd.Categorical([tissue_type for i in range(len(adata))])

adata.uns[UnsConstants.TITLE] = "Xenium_Preview_Human_Non_diseased_Lung_With_Add_on_FFPE_outs"
adata.var[VarConstants.FEATURE_IS_FILTERED] = False

adata.obs[ObsConstants.LIBRARY_KEY] = pd.Categorical(['section' for i in range(len(adata))])

# missing QC
# Convert X to float32 CSR matrix (required by CELLxGENE validator for raw data)
adata.X = csr_matrix(adata.X, dtype=np.float32)

# Filter out cells with zero counts across all genes (required by CELLxGENE validator)
sc.pp.filter_cells(adata, min_genes=1)

# run basic filtering with default values
# print(f"\nPerforming basic quality control for {geo_id}.")
# adata = qc_filter(adata=adata)

# logger.info(f"Cells after filtering zero-count cells: {adata.n_obs}")

# Set raw data so the CELLxGENE validator finds raw counts in adata.raw.X
adata.raw = adata
adata_output, valid, errors, is_seurat_convertible = validate(adata, organism=organism_validator)

adata_output.obs['assay'] = pd.Categorical(['Xenium' for i in range(len(adata_output))])
adata_output.obs[ObsConstants.ASSAY_ONTOLOGY_TERM_ID] = pd.Categorical(['no yet defined' for i in range(len(adata_output))])

adata_output.obs[ObsConstants.DATASET] = adata_output.uns['title']
adata_output.obs[ObsConstants.SPLIT] = 'train'
adata_output.obs[ObsConstants.NICHE] = 'nan'
adata_output.obs[ObsConstants.REGION] = 'nan'

adata_output.write(f"{preprocessed_path}/Xenium_Preview_Human_Non_diseased_Lung_With_Add_on_FFPE_outs.h5ad")
